# %%
import pandas as pd
import numpy as np

# %%
matches_df = pd.read_csv("matches_updated_mens_ipl_upto_2024.csv")

# %%
matches_df.head(2)
# Out:
#   eliminator                        team1 neutralvenue  balls_per_over  \
# 0        NaN  Royal Challengers Bangalore          NaN               6
# 1        NaN              Kings XI Punjab          NaN               6
#
#        umpire2    umpire1 outcome                                       venue  \
# 0  RE Koertzen  Asad Rauf     NaN                       M Chinnaswamy Stadium
# 1   SL Shastri  MR Benson     NaN  Punjab Cricket Association Stadium, Mohali
#
#   date1 date2  ...        city                 winner match_number  \
# 0   NaN   NaN  ...   Bangalore  Kolkata Knight Riders          1.0
# 1   NaN   NaN  ...  Chandigarh    Chennai Super Kings          2.0
#
#                    event  gender      match_referee  tv_umpire  \
# 0  Indian Premier League    male          J Srinath  AM Saheba
# 1  Indian Premier League    male  S Venkataraghavan  RB Tiffin
#
#                    toss_winner toss_decision matchId
# 0  Royal Challengers Bangalore         field  335982
# ...

# %%
deliveries_df = pd.read_csv("deliveries_updated_mens_ipl_upto_2024.csv")

# %%
deliveries_df.head(2)
# Out:
#    matchId  inning  over_ball  over  ball           batting_team  \
# 0   335982       1        0.1     0     1  Kolkata Knight Riders
# 1   335982       1        0.2     0     2  Kolkata Knight Riders
#
#                   bowling_team      batsman  non_striker   bowler  \
# 0  Royal Challengers Bangalore   SC Ganguly  BB McCullum  P Kumar
# 1  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extras  isWide  isNoBall  Byes  LegByes  Penalty  \
# 0             0       1     NaN       NaN   NaN      1.0      NaN
# 1             0       0     NaN       NaN   NaN      NaN      NaN
#
#   dismissal_kind player_dismissed        date
# 0            NaN              NaN  2008-04-18
# 1            NaN              NaN  2008-04-18

# %%
deliveries_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 260915    False
# 260916    False
# 260917    False
# 260918    False
# 260919    False
# Length: 260920, dtype: bool

# %%
len(deliveries_df)
# Out:
# 260920

# %%
deliveries_df.isnull().sum()
# Out:
# matchId                  0
# inning                   0
# over_ball                0
# over                     0
# ball                     0
# batting_team             0
# bowling_team             0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extras                   0
# isWide              252539
# isNoBall            259827
# Byes                260247
# LegByes             256919
# Penalty             260918
# dismissal_kind      247970
# player_dismissed    247970
# date                     0
# dtype: int64

# %%
# nan values in percentage with respect to each columns :
for feature in deliveries_df.columns :
    print(feature ,np.round((deliveries_df[feature].isnull().mean()*100),4))
# Out:
# matchId 0.0
# inning 0.0
# over_ball 0.0
# over 0.0
# ball 0.0
# batting_team 0.0
# bowling_team 0.0
# batsman 0.0
# non_striker 0.0
# bowler 0.0
# batsman_runs 0.0
# extras 0.0
# isWide 96.7879
# isNoBall 99.5811
# Byes 99.7421
# LegByes 98.4666
# Penalty 99.9992
# dismissal_kind 95.0368
# player_dismissed 95.0368
# date 0.0

# %%
deliveries_df['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %% [markdown]
# 'Royal Challengers Bengaluru' => Royal Challengers Bangalore'
#
# 'Rising Pune Supergiant'      => 'Rising Pune Supergiants'

# %%
# Replace values in 'Batting team' column
deliveries_df['batting_team'] = deliveries_df['batting_team'].replace({
    'Royal Challengers Bengaluru': 'Royal Challengers Bangalore',
    'Rising Pune Supergiant': 'Rising Pune Supergiants'
})

# Verify the replacements
print(deliveries_df['batting_team'].unique())
# Out:
# ['Kolkata Knight Riders' 'Royal Challengers Bangalore'
#  'Chennai Super Kings' 'Kings XI Punjab' 'Rajasthan Royals'
#  'Delhi Daredevils' 'Mumbai Indians' 'Deccan Chargers'
#  'Kochi Tuskers Kerala' 'Pune Warriors' 'Sunrisers Hyderabad'
#  'Rising Pune Supergiants' 'Gujarat Lions' 'Delhi Capitals' 'Punjab Kings'
#  'Lucknow Super Giants' 'Gujarat Titans']

# %%
deliveries_df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#        'Kings XI Punjab', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Rajasthan Royals', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
# Replace values in 'Bowling team'   column
deliveries_df['bowling_team'] = deliveries_df['bowling_team'].replace({
    'Royal Challengers Bengaluru': 'Royal Challengers Bangalore',
    'Rising Pune Supergiant': 'Rising Pune Supergiants'
})

# Verify the replacements
print(deliveries_df['bowling_team'].unique())
# Out:
# ['Royal Challengers Bangalore' 'Kolkata Knight Riders' 'Kings XI Punjab'
#  'Chennai Super Kings' 'Delhi Daredevils' 'Rajasthan Royals'
#  'Mumbai Indians' 'Deccan Chargers' 'Kochi Tuskers Kerala' 'Pune Warriors'
#  'Sunrisers Hyderabad' 'Rising Pune Supergiants' 'Gujarat Lions'
#  'Delhi Capitals' 'Punjab Kings' 'Gujarat Titans' 'Lucknow Super Giants']

# %%
# Save the processed data
deliveries_df.to_csv('/content/deliveries_update_2008_2024.csv', index=False)

# %%
df=pd.read_csv('/content/deliveries_updated_mens_ipl_upto_2024.csv')

# %%
df.head(2)
# Out:
#    matchId  inning  over_ball  over  ball           batting_team  \
# 0   335982       1        0.1     0     1  Kolkata Knight Riders
# 1   335982       1        0.2     0     2  Kolkata Knight Riders
#
#                   bowling_team      batsman  non_striker   bowler  \
# 0  Royal Challengers Bangalore   SC Ganguly  BB McCullum  P Kumar
# 1  Royal Challengers Bangalore  BB McCullum   SC Ganguly  P Kumar
#
#    batsman_runs  extras  isWide  isNoBall  Byes  LegByes  Penalty  \
# 0             0       1     NaN       NaN   NaN      1.0      NaN
# 1             0       0     NaN       NaN   NaN      NaN      NaN
#
#   dismissal_kind player_dismissed        date
# 0            NaN              NaN  2008-04-18
# 1            NaN              NaN  2008-04-18

# %%
df['player_dismissed'].unique()
# Out:
# array([nan, 'SC Ganguly', 'RT Ponting', 'DJ Hussey', 'R Dravid',
#        'V Kohli', 'JH Kallis', 'W Jaffer', 'MV Boucher', 'B Akhil',
#        'CL White', 'AA Noffke', 'Z Khan', 'SB Joshi', 'PA Patel',
#        'ML Hayden', 'MS Dhoni', 'SK Raina', 'JDP Oram', 'K Goel',
#        'JR Hopes', 'Yuvraj Singh', 'KC Sangakkara', 'T Kohli',
#        'YK Pathan', 'SR Watson', 'DS Lehmann', 'M Kaif', 'M Rawat',
#        'RA Jadeja', 'SK Warne', 'V Sehwag', 'L Ronchi', 'DJ Thornely',
#        'ST Jayasuriya', 'PR Shah', 'RV Uthappa', 'AM Nayar', 'SM Pollock',
#        'S Chanderpaul', 'LRPL Taylor', 'Y Venugopal Rao', 'VVS Laxman',
#        'AC Gilchrist', 'RG Sharma', 'SB Styris', 'AS Yadav', 'A Symonds',
#        'WPUJC Vaas', 'SB Bangar', 'PP Ojha', 'BB McCullum', 'WP Saha',
#        'Mohammad Hafeez', 'DPMD Jayawardene', 'IK Pathan', 'B Lee',
#        'S Sohal', 'Kamran Akmal', 'Shahid Afridi', 'G Gambhir',
#        'MEK Hussey', 'DJ Bravo', 'MA Khote', 'Harbhajan Singh',
# ...

# %%
# Assuming df is your DataFrame and it has a column 'player_dismissed'
df['iswicket'] = np.where(df['player_dismissed'].isna(), 0, 1)

# %%
df.columns
# Out:
# Index(['matchId', 'inning', 'over_ball', 'over', 'ball', 'batting_team',
#        'bowling_team', 'batsman', 'non_striker', 'bowler', 'batsman_runs',
#        'extras', 'isWide', 'isNoBall', 'Byes', 'LegByes', 'Penalty',
#        'dismissal_kind', 'player_dismissed', 'date', 'iswicket'],
#       dtype='object')

# %%
df['iswicket'].unique()
# Out:
# array([0, 1])

# %%
# Save the processed data
df.to_csv('/content/deliveries.csv', index=False)
